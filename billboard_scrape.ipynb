# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import requests
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
url = 'https://www.billboard.com/charts/hot-100/2017-11-04'
browser.visit(url)

# %%
html = browser.html
soup = bs(html, 'html.parser')

# %%
artist_list=[]
song_list=[]

# %%
top_song = soup.find('div', class_='chart-number-one__title').text.strip()
top_artist = soup.find('div', class_='chart-number-one__artist').text.strip()
artist_list.append(top_artist)
song_list.append(top_song)

# %%
results = soup.find_all('div',class_='chart-list-item')

# %%
for x in results:
    artist_name = x.find('div', class_='chart-list-item__artist').text
    artist_list.append(artist_name.strip())
    song_title=x.find('span', class_='chart-list-item__title-text').text
    song_list.append(song_title.strip())

# %%
Top_100_df=pd.DataFrame({'Artist':artist_list,'Song Title':song_list})

Top_100_df
# Out:
#                                                Artist  \
# 0                     Post Malone Featuring 21 Savage
# 1                                             Cardi B
# 2               Logic Featuring Alessia Cara & Khalid
# 3                                   Portugal. The Man
# 4                                     Imagine Dragons
# 5          J Balvin & Willy William Featuring Beyonce
# 6                                         Demi Lovato
# 7                                           Sam Smith
# 8                   French Montana Featuring Swae Lee
# 9                                        Taylor Swift
# 10                         Gucci Mane Featuring Migos
# 11                                       Charlie Puth
# 12                                               P!nk
# 13                                    Imagine Dragons
# 14  Luis Fonsi & Daddy Yankee Featuring Justin Bieber
# 15                                          21 Savage
# 16                     Yo Gotti Featuring Nicki Minaj
# 17                                         Ed Sheeran
# 18                             Maroon 5 Featuring SZA
# 19                Camila Cabello Featuring Young Thug
# 20                         Liam Payne Featuring Quavo
# 21                                         Ed Sheeran
# 22                                       Shawn Mendes
# 23                                        Niall Horan
# 24                                             Khalid
# 25                 Kane Brown Featuring Lauren Alaina
# 26                                           Lil Pump
# 27                                              Kesha
# 28                                        Post Malone
# 29                                         Bruno Mars
# ..                                                ...
# 70                    Gucci Mane Featuring The Weeknd
# 71                              Wisin Featuring Ozuna
# 72                                          Jon Pardi
# 73  Hailee Steinfeld & Alesso Featuring Florida Ge...
# 74                XXXTENTACION Featuring Trippie Redd
# 75                                        Post Malone
# 76                                       Chris Janson
# 77                                        Brett Young
# 78                                      Kenny Chesney
# 79                                        Chris Young
# 80                                       Lil Uzi Vert
# 81          Chris Brown Featuring Future & Young Thug
# 82                                       Maren Morris
# 83                                  Russell Dickerson
# 84                      Miguel Featuring Travis Scott
# 85                                           Jacquees
# 86                                                 NF
# 87                           Justin Bieber + BloodPop
# 88                                        Chris Brown
# 89                                MAX Featuring gnash
# 90                            Quavo, Takeoff & Offset
# 91                               Florida Georgia Line
# 92                                        Eric Church
# 93  Calvin Harris Featuring Pharrell Williams, Kat...
# 94      Gucci Mane Featuring Slim Jxmmi & Young Dolph
# 95                                       Walker Hayes
# 96                        Becky G Featuring Bad Bunny
# 97                                       Garth Brooks
# 98                                       Jason Aldean
# 99                                   Billy Currington
#
#                          Song Title
# 0                          Rockstar
# 1        Bodak Yellow (Money Moves)
# 2                    1-800-273-8255
# 3                     Feel It Still
# 4                           Thunder
# 5                          Mi Gente
# 6                   Sorry Not Sorry
# 7              Too Good At Goodbyes
# 8                     Unforgettable
# 9          Look What You Made Me Do
# 10                    I Get The Bag
# 11                        Attention
# 12                    What About Us
# 13                         Believer
# 14                        Despacito
# 15                     Bank Account
# 16                       Rake It Up
# 17                          Perfect
# 18                   What Lovers Do
# 19                           Havana
# 20                  Strip That Down
# 21                     Shape Of You
# 22  There's Nothing Holdin' Me Back
# 23                       Slow Hands
# 24               Young Dumb & Broke
# 25                         What Ifs
# 26                       Gucci Gang
# 27                          Praying
# 28                     I Fall Apart
# 29               That's What I Like
# ..                              ...
# 70                            Curve
# 71                 Escapate Conmigo
# 72     Heartache On The Dance Floor
# 73                        Let Me Go
# 74                        F**k Love
# 75                          Go Flex
# 76                      Fix A Drink
# 77                 Like I Loved You
# 78             All The Pretty Girls
# 79                     Losing Sleep
# 80                      Sauce It Up
# 81                         High End
# 82          I Could Use A Love Song
# 83                            Yours
# 84                       Sky Walker
# 85                           B.E.D.
# 86                     Let You Down
# 87                          Friends
# 88                        Questions
# 89                  Lights Down Low
# 90                        Too Hotty
# 91                           Smooth
# 92                  Round Here Buzz
# 93                            Feels
# 94            Stunting Ain't Nuthin
# 95             You Broke Up With Me
# 96                          Mayores
# 97                Ask Me How I Know
# 98                  They Don't Know
# 99              Do I Make You Wanna
#
# [100 rows x 2 columns]
